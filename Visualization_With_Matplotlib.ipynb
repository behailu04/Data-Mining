# %% [markdown]
# # Data Visualization Using Matplotlib
#
#                                  Behailu Dereje
#                                  May 27/2019

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
# setting styles
plt.style.use('classic')

# %%
x = np.linspace(0,10,100)
plt.plot(x, np.sin(x), '+')
plt.plot(x, np.cos(x), '--')

# %%
# labeling plots
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
           s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
# Visualizing 3D function
def f(x,y):
    return np.sin(x)** 10 + np.cos(10 + y * x) * np.cos(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors = 'red');

# %%
data = np.random.randn(10000)
plt.hist(data);

# %%
# Handwritten Digits
from sklearn.datasets import load_digits
digits = load_digits(n_class=6)

fig, ax = plt.subplots(8,8, figsize=(6,6))
for i, axi in enumerate(ax.flat):
    axi.imshow(digits.images[i], cmap='binary')
    axi.set(xticks=[], yticks=[])

# %%
theta = 2 * np.pi * np.random.random(1000)
r = 6 * np.random.random(1000)
x = np.ravel(r * np.sin(theta))
y = np.ravel(r * np.cos(theta))
z = f(x, y)

# %%
ax = plt.axes(projection='3d')
ax.scatter(x, y, z, c=z, cmap='viridis', linewidth=0.5);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-5075d66325c6> in <module>()
# ----> 1 ax = plt.axes(projection='3d')
#       2 ax.scatter(x, y, z, c=z, cmap='viridis', linewidth=0.5);
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in axes(arg, **kwargs)
#     909
#     910     if arg is None:
# --> 911         return subplot(111, **kwargs)
#     912
#     913     if isinstance(arg, Axes):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in subplot(*args, **kwargs)
#    1055
#    1056     fig = gcf()
# -> 1057     a = fig.add_subplot(*args, **kwargs)
#    1058     bbox = a.bbox
#    1059     byebye = []
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1237         else:
#    1238             projection_class, kwargs, key = process_projection_requirements(
# -> 1239                 self, *args, **kwargs)
#    1240
#    1241             # try to find the axes with this key in the stack
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/projections/__init__.pyc in process_projection_requirements(figure, *args, **kwargs)
#      89
#      90     if isinstance(projection, six.string_types) or projection is None:
# ---> 91         projection_class = get_projection_class(projection)
#      92     elif hasattr(projection, '_as_mpl_axes'):
#      93         projection_class, extra_kwargs = projection._as_mpl_axes()
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/projections/__init__.pyc in get_projection_class(projection)
#      63         return projection_registry.get_projection_class(projection)
#      64     except KeyError:
# ---> 65         raise ValueError("Unknown projection '%s'" % projection)
#      66
#      67
#
# ValueError: Unknown projection '3d'
